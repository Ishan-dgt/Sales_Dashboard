# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales.csv")
df
# Out:
#       Product  Price   Cost  Quantity        Date
# 0      Laptop  55000  45000         2  2025-01-10
# 1       Mouse    500    300        10  2025-01-12
# 2    Keyboard   1200    800         5  2025-02-05
# 3     Monitor  15000  12000         2  2025-02-15
# 4     Printer   9000   7000         1  2025-03-18
# 5  Headphones   2000   1400         6  2025-03-22

# %%
df["Revenue"] = df["Price"] * df["Quantity"]
df["Profit"] = (df["Price"] - df["Cost"]) * df["Quantity"]

df
# Out:
#       Product  Price   Cost  Quantity        Date  Revenue  Profit
# 0      Laptop  55000  45000         2  2025-01-10   110000   20000
# 1       Mouse    500    300        10  2025-01-12     5000    2000
# 2    Keyboard   1200    800         5  2025-02-05     6000    2000
# 3     Monitor  15000  12000         2  2025-02-15    30000    6000
# 4     Printer   9000   7000         1  2025-03-18     9000    2000
# 5  Headphones   2000   1400         6  2025-03-22    12000    3600

# %%
total_revenue = df["Revenue"].sum()
total_profit = df["Profit"].sum()
best_product = df.groupby("Product")["Revenue"].sum().idxmax()

print("Total Revenue :", total_revenue)
print("Total Profit  :", total_profit)
print("Best Product  :", best_product)
# Out:
# Total Revenue : 172000
# Total Profit  : 35600
# Best Product  : Laptop

# %%
product_revenue = df.groupby("Product")["Revenue"].sum()

plt.figure()
product_revenue.plot(kind="bar")
plt.title("Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.show()

# %%
product_profit = df.groupby("Product")["Profit"].sum()

plt.figure()
product_profit.plot(kind="bar")
plt.title("Profit by Product")
plt.xlabel("Product")
plt.ylabel("Profit")
plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Month"] = df["Date"].dt.to_period("M")

monthly_revenue = df.groupby("Month")["Revenue"].sum()

plt.figure()
monthly_revenue.plot(marker="o")
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
plt.figure()
product_revenue.plot(kind="pie", autopct="%1.1f%%")
plt.title("Revenue Distribution by Product")
plt.ylabel("")
plt.show()
